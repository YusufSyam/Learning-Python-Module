# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv('survey_results_public.csv')
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %% [markdown]
# Filter data hanya dari negara India saja

# %%
filt= df['Country']=='India'
df[filt]
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 6               7          I am a developer by profession      Yes   NaN
# 21             22          I am a developer by profession      Yes   NaN
# 57             58          I am a developer by profession      Yes   NaN
# 62             63  I am a student who is learning to code      Yes  21.0
# 147           149          I am a developer by profession      Yes  36.0
# ...           ...                                     ...      ...   ...
# 64391       54757                                     NaN      Yes   NaN
# 64398       55407                                     NaN      Yes   NaN
# 64439       62464                                     NaN      Yes   NaN
# 64442       62954                                     NaN      Yes   NaN
# 64452       64236                                     NaN      Yes   NaN
#
#       Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# ...

# %% [markdown]
# Bisa juga seperti ini

# %%
df[df['Country']=='India'].head()
# Out:
#      Respondent                              MainBranch Hobbyist   Age  \
# 6             7          I am a developer by profession      Yes   NaN
# 21           22          I am a developer by profession      Yes   NaN
# 57           58          I am a developer by profession      Yes   NaN
# 62           63  I am a student who is learning to code      Yes  21.0
# 147         149          I am a developer by profession      Yes  36.0
#
#     Age1stCode CompFreq   CompTotal  ConvertedComp Country  \
# 6           18  Monthly         NaN            NaN   India
# 21          18  Monthly         NaN            NaN   India
# 57          22      NaN         NaN            NaN   India
# 62          17      NaN         NaN            NaN   India
# 147         31   Yearly  21000000.0       293196.0   India
#
#              CurrencyDesc  ...                  SurveyEase  \
# 6    United States dollar  ...                         NaN
# 21           Indian rupee  ...                        Easy
# ...

# %% [markdown]
# Filter data hanya India **atau** Germany

# %%
filt= (df['Country']=='India') | (df['Country']=='Germany')
df[filt]
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 0               1  I am a developer by profession      Yes   NaN         13
# 5               6  I am a developer by profession       No   NaN         14
# 6               7  I am a developer by profession      Yes   NaN         18
# 21             22  I am a developer by profession      Yes   NaN         18
# 22             23  I am a developer by profession      Yes  27.0         14
# ...           ...                             ...      ...   ...        ...
# 64398       55407                             NaN      Yes   NaN        NaN
# 64402       56263                             NaN      Yes   NaN         14
# 64439       62464                             NaN      Yes   NaN        NaN
# 64442       62954                             NaN      Yes   NaN        NaN
# 64452       64236                             NaN      Yes   NaN        NaN
#
# ...

# %% [markdown]
# Filter data orang bernegara India **dan** berumur di atas 20

# %%
filt= (df['Country']=='India') & (df['Age']>20)
df[filt]
# Out:
#        Respondent                              MainBranch Hobbyist   Age  \
# 62             63  I am a student who is learning to code      Yes  21.0
# 147           149          I am a developer by profession      Yes  36.0
# 225           227          I am a developer by profession      Yes  24.0
# 232           234          I am a developer by profession      Yes  22.0
# 272           274          I am a developer by profession      Yes  26.0
# ...           ...                                     ...      ...   ...
# 62211       63515  I am a student who is learning to code      Yes  22.0
# 62522       63850  I am a student who is learning to code      Yes  21.0
# 63546       64969          I am a developer by profession      Yes  21.0
# 63716       65149  I am a student who is learning to code      Yes  21.0
# 64278       31248                                     NaN      Yes  35.0
#
#       Age1stCode CompFreq   CompTotal  ConvertedComp Country  CurrencyDesc  \
# ...
